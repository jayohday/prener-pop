# %%
import pandas as pd

# %%
df = pd.read_csv('./STL_DEMOGRAPHY_NhoodPop/data/clean/STL_RaceByNhood.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 32 columns):
# NHD_NAME      79 non-null object
# NHD_NUM       79 non-null int64
# white40       79 non-null float64
# nonwhite40    79 non-null float64
# white50       79 non-null float64
# black50       79 non-null float64
# white60       79 non-null float64
# black60       79 non-null float64
# white70       79 non-null float64
# black70       79 non-null float64
# white80       79 non-null float64
# black80       79 non-null float64
# white90       79 non-null float64
# black90       79 non-null float64
# white00       79 non-null float64
# black00       79 non-null float64
# white10       79 non-null float64
# black10       79 non-null float64
# white11       79 non-null float64
# black11       79 non-null float64
# white12       79 non-null float64
# black12       79 non-null float64
# white13       79 non-null float64
# black13       79 non-null float64
# ...

# %%
df.head(5)
# Out:
#             NHD_NAME  NHD_NUM      white40   nonwhite40      white50  \
# 0         Franz Park       43  3306.505367     2.486677  3298.638697
# 1            Tiffany       29  3214.008581  1067.824981  3012.896540
# 2  Botanical Heights       28  6299.283679    13.187813  5856.631529
# 3          Kings Oak       40   397.656850     6.874470   388.013514
# 4         Cheltenham       41  2084.580712    43.798188  2254.289460
#
#        black50      white60      black60      white70      black70  ...  \
# 0     1.469013  3426.582823     0.021713  3025.697656    24.828459  ...
# 1  1399.903682  2406.451301  1262.906332   981.745947  1542.880946  ...
# 2     9.949579  5290.322148    36.111413  3935.426311    46.343503  ...
# 3     0.133074   311.862987     0.086822   264.983427     2.706811  ...
# 4    24.112963  2108.557227    24.580194  1234.876438    18.240670  ...
#
#        white13     black13      white14     black14      white15     black15  \
# ...

# %%
df['50_10_white_change'] = df['white10'] - df['white50']

# %%
df['50_10_black_change'] = df['black10'] - df['black50']

# %%
df.set_index('NHD_NAME')
# Out:
#                             NHD_NUM       white40    nonwhite40       white50  \
# NHD_NAME
# Franz Park                       43   3306.505367      2.486677   3298.638697
# Tiffany                          29   3214.008581   1067.824981   3012.896540
# Botanical Heights                28   6299.283679     13.187813   5856.631529
# Kings Oak                        40    397.656850      6.874470    388.013514
# Cheltenham                       41   2084.580712     43.798188   2254.289460
# Clayton-Tamm                     42   3569.628075     36.900610   4073.812376
# Forest Park South East           39   8056.005438    168.357604   7474.905689
# Hi-Pointe                        44   3600.868606      6.304442   4218.445708
# Downtown West                    36   4776.183517  12656.861437   4539.376967
# Midtown                          37   5115.540720  14617.776314   5209.310238
# Columbus Square                  62   1832.286949   2788.620590   1141.104970
# ...

# %%
black_sort = df.sort_values('50_10_black_change')

# %%
white_sort = df.sort_values('50_10_white_change')

# %%
print black_sort
# Out:
#                       NHD_NAME  NHD_NUM       white40    nonwhite40  \
# 14            Central West End       38  35088.719982   1812.203575
# 66       Near North Riverfront       64  23267.369813    617.127736
# 67            Wells Goodfellow       50  22235.586395    135.339482
# 25                    West End       48  20705.888709    339.679531
# 17             St. Louis Place       60  21397.318248    699.044474
# 38                   Dutchtown       16  24475.315011     46.785479
# 50                     Soulard       21  16385.889760    122.874499
# 21              Jeff Vanderlou       59  19968.830551  16141.686515
# 45           Tower Grove South       15  22301.830135     16.476101
# 54                        Shaw       27  15609.447968     27.980039
# 28            Hamilton Heights       78  14134.343792     38.285966
# 26               Greater Ville       56  17150.369444   5245.085641
# 65                     Penrose       69  12931.324871     14.750157
# ...
